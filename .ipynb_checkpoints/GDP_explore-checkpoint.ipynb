# %% [markdown]
# # Exploring some GDP numbers, modeling
#
# To get a sense of forecasting GDP using different methods - but first need to explore GDP. Will focus on Canadian GDP, with data from Stats Can

# %% [markdown]
# First need to install* Stats_Can library

# %%
import sys
# !conda install -c ian.e.preston --yes --prefix {sys.prefix} stats_can
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Maln\Anaconda3
#
#   added / updated specs:
#     - stats_can
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     stats_can-2.2.2            |             py_1        11.8 MB  ian.e.preston
#     ------------------------------------------------------------
#                                            Total:        11.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   stats_can          ian.e.preston/noarch::stats_can-2.2.2-py_1
#
#
#
# ...
#
# stats_can-2.2.2      | 11.8 MB   |            |   0%
# stats_can-2.2.2      | 11.8 MB   |            |   0%
# stats_can-2.2.2      | 11.8 MB   |            |   1%
# stats_can-2.2.2      | 11.8 MB   | 1          |   1%
# stats_can-2.2.2      | 11.8 MB   | 2          |   2%
# stats_can-2.2.2      | 11.8 MB   | 3          |   3%
# ...

# %% [markdown]
# Default imports

# %%
from stats_can import StatsCan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#seaborn 
import seaborn as sns
sns.set()

# %% [markdown]
# importing GDP based on income table first

# %%
sc=StatsCan()
gdp_inc = sc.table_to_df(' 36-10-0103-01 ')

# %% [markdown]
# Importing note in economic activity in this time - wages and how wages affect GDP, are affected by the pandemic closures

# %%
wages = sc.table_to_df(' 36-10-0205-01 ')

# %%
gdp_inc
# Out:
#        REF_DATE     GEO           DGUID                  Seasonal adjustment  \
# 0    1961-01-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 1    1961-01-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 2    1961-01-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 3    1961-01-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# 4    1961-01-01  Canada  2016A000011124  Seasonally adjusted at annual rates
# ...         ...     ...             ...                                  ...
# 6603 2019-10-01  Canada  2016A000011124                           Unadjusted
# 6604 2019-10-01  Canada  2016A000011124                           Unadjusted
# 6605 2019-10-01  Canada  2016A000011124                           Unadjusted
# 6606 2019-10-01  Canada  2016A000011124                           Unadjusted
# 6607 2019-10-01  Canada  2016A000011124                           Unadjusted
#
# ...

# %%
wages
# Out:
#         REF_DATE             GEO           DGUID  \
# 0     1997-01-01          Canada  2016A000011124
# 1     1997-01-01          Canada  2016A000011124
# 2     1997-01-01          Canada  2016A000011124
# 3     1997-01-01          Canada  2016A000011124
# 4     1997-01-01          Canada  2016A000011124
# ...          ...             ...             ...
# 92971 2019-12-01  Outside Canada             NaN
# 92972 2019-12-01  Outside Canada             NaN
# 92973 2019-12-01  Outside Canada             NaN
# 92974 2019-12-01  Outside Canada             NaN
# 92975 2019-12-01  Outside Canada             NaN
#
#                                 Sector  Seasonal adjustment      UOM UOM_ID  \
# 0            Compensation of employees           Unadjusted  Dollars     81
# 1            Compensation of employees  Seasonally adjusted  Dollars     81
# 2                   Wages and salaries           Unadjusted  Dollars     81
# ...

# %%
retail_trade = sc.table_to_df(' 20-10-0008-01 ')
